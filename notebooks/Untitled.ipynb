# %%
from src.preprocess import load_and_clean, scale_features

df = load_and_clean("../data/synthetic_schools.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.preprocess import load_and_clean, scale_features
#       3 df = load_and_clean("../data/synthetic_schools.csv")
#
# ModuleNotFoundError: No module named 'src'
